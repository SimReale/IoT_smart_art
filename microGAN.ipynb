# %%
import pandas as pd

data =pd.read_csv('art_installation_dataset.csv')
data.head()
# Out:
#              Timestamp  Light_Intensity  Sound_Level  Motion_Density  \
# 0  2025-01-01 12:00:00              115           80            0.64
# 1  2025-01-01 12:00:05              197           45            0.52
# 2  2025-01-01 12:00:10              375           68            0.40
# 3  2025-01-01 12:00:15              457           54            0.05
# 4  2025-01-01 12:00:20              453           89            0.20
#
#    Temperature  Humidity       Light_RGB  Brightness  Anim_Speed      Style  \
# 0           26        55   (12, 130, 22)         220           1      fluid
# 1           27        60  (239, 89, 219)         154           5  geometric
# 2           24        46   (97, 44, 254)          72           7   abstract
# 3           21        58   (155, 9, 107)          87           5      fluid
# 4           22        50  (140, 153, 97)         239           9   abstract
#
#    Complexity  Confidence  Engagement_Time User_Sentiment  Interaction_Freq  \
# ...
